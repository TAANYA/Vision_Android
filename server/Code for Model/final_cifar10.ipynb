# %% [markdown]
# # Object recognition on cifar10 dataset using CNN

# %% [markdown]
# ###### Using keras to import  cifar10 dataset

# %%
from keras.datasets import cifar10
from matplotlib import pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ###### Loading data

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
for i in range(0, 9):
    plt.subplot(330 + 1 + i)
    plt.imshow(X_train[i])
# show the plot
plt.show()

# %%
print  X_train.shape ,  y_train.shape
print X_test.shape , y_test.shape
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
print 'training data:', X_train.shape[0]
print 'test data:' , X_test.shape[0]
# Out:
# training data: 50000
# test data: 10000

# %%
print "dimension of a single image :", X_train[1].shape
# Out:
# dimension of a single image : (32, 32, 3)

# %% [markdown]
# ###### 32*32 dimensions with 3 channels ->RGB

# %%
print "for first channel :"
print X_train[1][:,:,0]
# Out:
# for first channel :
# [[154 126 105 ...,  91  87  79]
#  [140 145 125 ...,  96  77  71]
#  [140 139 115 ...,  79  68  67]
#  ...,
#  [175 156 154 ...,  42  61  93]
#  [165 156 159 ..., 103 123 131]
#  [163 158 163 ..., 143 143 143]]

# %% [markdown]
# ###### importing libraries for model contruction

# %%
import numpy as np
from keras.callbacks import EarlyStopping
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Flatten 
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam
from keras.layers.pooling import MaxPooling2D
from keras.utils import np_utils
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.normalization import BatchNormalization

# %%
num_classes = 10
epochs = 200
data_augmentation = False
num_predictions = 30
batch_size = 128

# %% [markdown]
# ###### Data Preprocessing like normalization and  one hot vectorization

# %%
X_train = X_train/255.0
X_test = X_test/255.0

y_train = np_utils.to_categorical(y_train, num_classes)
y_test = np_utils.to_categorical(y_test , num_classes)

# %%
print "normalized pixel values  for first channel :\n\n" , X_train[1][: , : , 0]
# Out:
# normalized pixel values  for first channel :
#
# [[ 0.60392157  0.49411765  0.41176471 ...,  0.35686275  0.34117647
#    0.30980392]
#  [ 0.54901961  0.56862745  0.49019608 ...,  0.37647059  0.30196078
#    0.27843137]
#  [ 0.54901961  0.54509804  0.45098039 ...,  0.30980392  0.26666667
#    0.2627451 ]
#  ...,
#  [ 0.68627451  0.61176471  0.60392157 ...,  0.16470588  0.23921569
#    0.36470588]
#  [ 0.64705882  0.61176471  0.62352941 ...,  0.40392157  0.48235294
#    0.51372549]
#  [ 0.63921569  0.61960784  0.63921569 ...,  0.56078431  0.56078431
#    0.56078431]]

# %%
print "new shape for y-train :",  y_train.shape
# Out:
# new shape for y-train : (50000, 10)

# %% [markdown]
# ###### Creating the Model

# %%
model = Sequential()

model.add(Conv2D(32,(3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# ######  Summary of the Model

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 776,394
# Trainable params: 776,394
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###### Initiating adams optimizer

# %%
opt  = Adam(lr=0.0001, decay=1e-6)

# %% [markdown]
# ###### Compiling the Model

# %%
model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])

# %% [markdown]
# ###### Fitting the Model

# %%
if not data_augmentation:
    print('Not using data augmentation.')
    hist = model.fit(X_train, y_train,
              batch_size=batch_size,
              nb_epoch=epochs,
              validation_data=(X_test, y_test),
              callbacks=[EarlyStopping(min_delta=0.001, patience=3)],
              shuffle=True)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False) # randomly flip images

        # Compute quantities required for feature-wise normalization
        # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(X_train)

        # Fit the model on the batches generated by datagen.flow().
    hist_with_augmentation = model.fit_generator(datagen.flow(X_train, y_train,
                                batch_size=batch_size),
                                samples_per_epoch=x_train.shape[0] // batch_size,
                                nb_epoch=epochs, validation_data = (X_test, y_test),
                       callbacks=[EarlyStopping(min_delta=0.001, patience=3)])
# Out:
# Not using data augmentation.
# /home/shuja1497/anaconda2/lib/python2.7/site-packages/keras/models.py:851: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/200
# 50000/50000 [==============================] - 345s - loss: 1.9586 - acc: 0.2721 - val_loss: 1.6957 - val_acc: 0.3844
# Epoch 2/200
# 50000/50000 [==============================] - 274s - loss: 1.6291 - acc: 0.3993 - val_loss: 1.4941 - val_acc: 0.4586
# Epoch 3/200
# 50000/50000 [==============================] - 271s - loss: 1.4890 - acc: 0.4531 - val_loss: 1.4004 - val_acc: 0.4950
# Epoch 4/200
# 50000/50000 [==============================] - 271s - loss: 1.4007 - acc: 0.4887 - val_loss: 1.2964 - val_acc: 0.5332
# Epoch 5/200
# 50000/50000 [==============================] - 273s - loss: 1.3276 - acc: 0.5182 - val_loss: 1.2317 - val_acc: 0.5620
# Epoch 6/200
# 50000/50000 [==============================] - 273s - loss: 1.2708 - acc: 0.5447 - val_loss: 1.2152 - val_acc: 0.5637
# Epoch 7/200
# 50000/50000 [==============================] - 272s - loss: 1.2214 - acc: 0.5640 - val_loss: 1.1450 - val_acc: 0.5958
# Epoch 8/200
# 50000/50000 [==============================] - 273s - loss: 1.1800 - acc: 0.5810 - val_loss: 1.1573 - val_acc: 0.5895
# Epoch 9/200
# 50000/50000 [==============================] - 272s - loss: 1.1435 - acc: 0.5938 - val_loss: 1.0631 - val_acc: 0.6270
# Epoch 10/200
# 50000/50000 [==============================] - 275s - loss: 1.1126 - acc: 0.6062 - val_loss: 1.0514 - val_acc: 0.6298
# Epoch 11/200
# 50000/50000 [==============================] - 271s - loss: 1.0790 - acc: 0.6171 - val_loss: 1.0201 - val_acc: 0.6420
# Epoch 12/200
# 50000/50000 [==============================] - 272s - loss: 1.0492 - acc: 0.6298 - val_loss: 0.9792 - val_acc: 0.6615
# Epoch 13/200
# 50000/50000 [==============================] - 273s - loss: 1.0237 - acc: 0.6404 - val_loss: 0.9749 - val_acc: 0.6605
# Epoch 14/200
# 50000/50000 [==============================] - 269s - loss: 0.9995 - acc: 0.6495 - val_loss: 0.9417 - val_acc: 0.6714
# Epoch 15/200
# 50000/50000 [==============================] - 274s - loss: 0.9753 - acc: 0.6567 - val_loss: 0.9334 - val_acc: 0.6787
# Epoch 16/200
# 50000/50000 [==============================] - 272s - loss: 0.9606 - acc: 0.6641 - val_loss: 0.9082 - val_acc: 0.6864
# Epoch 17/200
# 50000/50000 [==============================] - 271s - loss: 0.9347 - acc: 0.6743 - val_loss: 0.8926 - val_acc: 0.6914
# Epoch 18/200
# 50000/50000 [==============================] - 270s - loss: 0.9183 - acc: 0.6792 - val_loss: 0.8706 - val_acc: 0.6970
# Epoch 19/200
# 50000/50000 [==============================] - 271s - loss: 0.8999 - acc: 0.6856 - val_loss: 0.8588 - val_acc: 0.6979
# Epoch 20/200
# 50000/50000 [==============================] - 271s - loss: 0.8810 - acc: 0.6922 - val_loss: 0.8545 - val_acc: 0.7038
# Epoch 21/200
# 50000/50000 [==============================] - 273s - loss: 0.8722 - acc: 0.6945 - val_loss: 0.8321 - val_acc: 0.7154
# Epoch 22/200
# 50000/50000 [==============================] - 273s - loss: 0.8516 - acc: 0.7005 - val_loss: 0.8347 - val_acc: 0.7118
# Epoch 23/200
# 50000/50000 [==============================] - 269s - loss: 0.8349 - acc: 0.7077 - val_loss: 0.7984 - val_acc: 0.7251
# Epoch 24/200
# 50000/50000 [==============================] - 274s - loss: 0.8228 - acc: 0.7130 - val_loss: 0.8234 - val_acc: 0.7181
# Epoch 25/200
# 50000/50000 [==============================] - 270s - loss: 0.8064 - acc: 0.7183 - val_loss: 0.7977 - val_acc: 0.7252
# Epoch 26/200
# 50000/50000 [==============================] - 273s - loss: 0.7969 - acc: 0.7215 - val_loss: 0.7881 - val_acc: 0.7275
# Epoch 27/200
# 50000/50000 [==============================] - 272s - loss: 0.7782 - acc: 0.7287 - val_loss: 0.7650 - val_acc: 0.7344
# Epoch 28/200
# 50000/50000 [==============================] - 272s - loss: 0.7655 - acc: 0.7323 - val_loss: 0.7565 - val_acc: 0.7368
# Epoch 29/200
# 50000/50000 [==============================] - 271s - loss: 0.7544 - acc: 0.7354 - val_loss: 0.7595 - val_acc: 0.7359
# Epoch 30/200
# 50000/50000 [==============================] - 272s - loss: 0.7421 - acc: 0.7408 - val_loss: 0.7422 - val_acc: 0.7417
# Epoch 31/200
# 50000/50000 [==============================] - 272s - loss: 0.7320 - acc: 0.7439 - val_loss: 0.7310 - val_acc: 0.7453
# Epoch 32/200
# 50000/50000 [==============================] - 274s - loss: 0.7207 - acc: 0.7485 - val_loss: 0.7572 - val_acc: 0.7359
# Epoch 33/200
# 50000/50000 [==============================] - 271s - loss: 0.7093 - acc: 0.7530 - val_loss: 0.7142 - val_acc: 0.7513
# Epoch 34/200
# 50000/50000 [==============================] - 274s - loss: 0.6977 - acc: 0.7560 - val_loss: 0.7094 - val_acc: 0.7508
# Epoch 35/200
# 50000/50000 [==============================] - 272s - loss: 0.6901 - acc: 0.7562 - val_loss: 0.7014 - val_acc: 0.7562
# Epoch 36/200
# 50000/50000 [==============================] - 273s - loss: 0.6752 - acc: 0.7652 - val_loss: 0.7030 - val_acc: 0.7550
# Epoch 37/200
# 50000/50000 [==============================] - 271s - loss: 0.6651 - acc: 0.7661 - val_loss: 0.6827 - val_acc: 0.7608
# Epoch 38/200
# 50000/50000 [==============================] - 276s - loss: 0.6556 - acc: 0.7711 - val_loss: 0.7050 - val_acc: 0.7546
# Epoch 39/200
# 50000/50000 [==============================] - 272s - loss: 0.6482 - acc: 0.7733 - val_loss: 0.6730 - val_acc: 0.7653
# Epoch 40/200
# 50000/50000 [==============================] - 271s - loss: 0.6408 - acc: 0.7771 - val_loss: 0.6680 - val_acc: 0.7683
# Epoch 41/200
# 50000/50000 [==============================] - 269s - loss: 0.6282 - acc: 0.7798 - val_loss: 0.6664 - val_acc: 0.7678
# Epoch 42/200
# 50000/50000 [==============================] - 270s - loss: 0.6218 - acc: 0.7799 - val_loss: 0.6657 - val_acc: 0.7707
# Epoch 43/200
# 50000/50000 [==============================] - 274s - loss: 0.6128 - acc: 0.7843 - val_loss: 0.6644 - val_acc: 0.7698
# Epoch 44/200
# 50000/50000 [==============================] - 273s - loss: 0.6061 - acc: 0.7866 - val_loss: 0.6643 - val_acc: 0.7689
# Epoch 45/200
# 50000/50000 [==============================] - 272s - loss: 0.5981 - acc: 0.7913 - val_loss: 0.6564 - val_acc: 0.7707
# Epoch 46/200
# 50000/50000 [==============================] - 273s - loss: 0.5878 - acc: 0.7926 - val_loss: 0.6465 - val_acc: 0.7780
# Epoch 47/200
# 50000/50000 [==============================] - 270s - loss: 0.5791 - acc: 0.7970 - val_loss: 0.6558 - val_acc: 0.7757
# Epoch 48/200
# 50000/50000 [==============================] - 270s - loss: 0.5745 - acc: 0.7984 - val_loss: 0.6398 - val_acc: 0.7785
# Epoch 49/200
# 50000/50000 [==============================] - 271s - loss: 0.5673 - acc: 0.8009 - val_loss: 0.6298 - val_acc: 0.7820
# Epoch 50/200
# 50000/50000 [==============================] - 275s - loss: 0.5547 - acc: 0.8052 - val_loss: 0.6481 - val_acc: 0.7773
# Epoch 51/200
# 50000/50000 [==============================] - 272s - loss: 0.5491 - acc: 0.8074 - val_loss: 0.6263 - val_acc: 0.7845
# Epoch 52/200
# 50000/50000 [==============================] - 272s - loss: 0.5453 - acc: 0.8081 - val_loss: 0.6267 - val_acc: 0.7852
# Epoch 53/200
# 50000/50000 [==============================] - 272s - loss: 0.5380 - acc: 0.8105 - val_loss: 0.6214 - val_acc: 0.7849
# Epoch 54/200
# 50000/50000 [==============================] - 271s - loss: 0.5322 - acc: 0.8116 - val_loss: 0.6151 - val_acc: 0.7885
# Epoch 55/200
# 50000/50000 [==============================] - 271s - loss: 0.5196 - acc: 0.8179 - val_loss: 0.6329 - val_acc: 0.7805
# Epoch 56/200
# 50000/50000 [==============================] - 273s - loss: 0.5210 - acc: 0.8160 - val_loss: 0.6187 - val_acc: 0.7859
# Epoch 57/200
# 50000/50000 [==============================] - 272s - loss: 0.5075 - acc: 0.8214 - val_loss: 0.6155 - val_acc: 0.7911
# Epoch 58/200
# 50000/50000 [==============================] - 271s - loss: 0.5047 - acc: 0.8210 - val_loss: 0.6170 - val_acc: 0.7872

# %% [markdown]
#       The validation accuracy reaches 0.79 after 60 epochs when the early stopping terminates the process because the  validation loss has stopped decreasing (the final value is about 0.6).

# %% [markdown]
# ###### the above model reaches an accuracy of around 79% with 60 epochs having a batch size of 128 and the optimizer being used is adam's optimizer

# %% [markdown]
# ###### model evaluation :

# %%
scores = model.evaluate(X_test , y_test)
print('Loss: %.3f' % scores[0])
print('Accuracy: %.3f' % scores[1])
# Out:
# 10000/10000 [==============================] - 11s
# Loss: 0.617
# Accuracy: 0.787

# %%
h_data = hist.history

# %%
print h_data
print h_data.keys()
# Out:
# {'acc': [0.27212000001907349, 0.39933999999999997, 0.45310000001907347, 0.48868000003814699, 0.51820000001907351, 0.54468000000000005, 0.56401999999999997, 0.58104, 0.59381999998092649, 0.60624000001907352, 0.61705999998092653, 0.62975999998092647, 0.64044000000000001, 0.64954000000000001, 0.65666000001907343, 0.66413999996185302, 0.67428000001907351, 0.67916000001907351, 0.68555999999999995, 0.69220000000000004, 0.69446000001907349, 0.70054000003814698, 0.70767999998092657, 0.71297999999999995, 0.71829999998092653, 0.72153999996185303, 0.72870000000000001, 0.73232000003814701, 0.735420000038147, 0.74076000003814702, 0.74393999998092653, 0.74850000001907346, 0.75299999998092648, 0.75602000003814696, 0.75624000000000002, 0.76522000003814694, 0.76606000001907348, 0.77114000001907346, 0.77331999998092649, 0.77706000003814701, 0.77976000001907353, 0.7798799999809265, 0.7842800000190735, 0.786559999961853, 0.79128000003814702, 0.79257999999999995, 0.79696, 0.79836000001907348, 0.80085999996185298, 0.80515999996185306, 0.80744000003814698, 0.80808000001907354, 0.810460000038147, 0.81162000001907353, 0.81794, 0.81601999998092656, 0.82142000003814697, 0.82098000001907345], 'loss': [1.9585537802505493, 1.6291205836868285, 1.4889747708892822, 1.4007476267242431, 1.327574956703186, 1.2707836258697509, 1.2214340712738037, 1.1799654235458374, 1.1435394836044313, 1.1126490955352784, 1.079011810722351, 1.0492042590332031, 1.0237178211975098, 0.99946623065948481, 0.97525449888229365, 0.9606109561538696, 0.93466861454010008, 0.91830120605468746, 0.89989532209396361, 0.88097794929504392, 0.87215820148468015, 0.85160800865173336, 0.83492663101196285, 0.82276158493041995, 0.80639848346710208, 0.79685200452804561, 0.77815502292633054, 0.76554962036132812, 0.75435378704071043, 0.74209474819183352, 0.73202416257858272, 0.72067334817886353, 0.70931845893859868, 0.69774826801300049, 0.69008283363342282, 0.6752062963867187, 0.66509813789367678, 0.65564430753707881, 0.64817508964538573, 0.64083540504455572, 0.6281903467559814, 0.62177640796661382, 0.61280207597732539, 0.60608432790756228, 0.59805293579101559, 0.58783885684967041, 0.57913388870239257, 0.57447205846786498, 0.56726340951919552, 0.55474269962310796, 0.54905790399551391, 0.54530334386825563, 0.53804458412170408, 0.53221311164855956, 0.51963568241119384, 0.52097927549362177, 0.50754922532081603, 0.50468559228897092], 'val_acc': [0.38440000000000002, 0.45860000000000001, 0.495, 0.53320000000000001, 0.56200000000000006, 0.56369999999999998, 0.5958, 0.58950000000000002, 0.627, 0.62980000000000003, 0.64200000000000002, 0.66149999999999998, 0.66049999999999998, 0.6714, 0.67869999999999997, 0.68640000000000001, 0.69140000000000001, 0.69699999999999995, 0.69789999999999996, 0.70379999999999998, 0.71540000000000004, 0.71179999999999999, 0.72509999999999997, 0.71809999999999996, 0.72519999999999996, 0.72750000000000004, 0.73440000000000005, 0.73680000000000001, 0.7359, 0.74170000000000003, 0.74529999999999996, 0.7359, 0.75129999999999997, 0.75080000000000002, 0.75619999999999998, 0.755, 0.76080000000000003, 0.75460000000000005, 0.76529999999999998, 0.76829999999999998, 0.76780000000000004, 0.77070000000000005, 0.76980000000000004, 0.76890000000000003, 0.77070000000000005, 0.77800000000000002, 0.77569999999999995, 0.77849999999999997, 0.78200000000000003, 0.77729999999999999, 0.78449999999999998, 0.78520000000000001, 0.78490000000000004, 0.78849999999999998, 0.78049999999999997, 0.78590000000000004, 0.79110000000000003, 0.78720000000000001], 'val_loss': [1.6956648843765258, 1.4941258949279785, 1.400405192375183, 1.2964238832473756, 1.2317130758285522, 1.2151608383178711, 1.1449645799636841, 1.1573135204315186, 1.0631398096084594, 1.0513613334655763, 1.0201174650192262, 0.97922631835937501, 0.97494213113784789, 0.94172635116577152, 0.93340024261474608, 0.90819150447845454, 0.89258541650772094, 0.87062172393798831, 0.85877021064758297, 0.85453809661865232, 0.83207271633148194, 0.83474719543457032, 0.7983 ...
# ['acc', 'loss', 'val_acc', 'val_loss']

# %% [markdown]
# ## Visualization for loss and accuracy of the model

# %%
plt.figure(figsize=(14,3))
plt.subplot(1, 2, 1)
plt.suptitle('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.xlabel('Epochs', fontsize=16)

plt.plot(hist.history['loss'], 'b--', label='Training Loss', linewidth=3)
plt.plot(hist.history['val_loss'], 'r', label='Validation Loss' ,linewidth=3)
plt.legend(loc='upper right')

plt.subplot(1, 2, 2)
plt.ylabel('Accuracy', fontsize=16)
plt.xlabel('Epochs', fontsize=16)
plt.plot(hist.history['acc'], 'b--', label='Training Accuracy' , linewidth=3)
plt.plot(hist.history['val_acc'], 'r', label='Validation Accuracy' , linewidth=3)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# #### Prediction Analysis

# %%
import os
import pickle
import numpy as np

# %%
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'modelforserver.h5'

# %% [markdown]
# ######  saving model in HDF5 file for prediction purpose

# %%
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at /home/shuja1497/study/OpenSourceProject/server/saved_models/modelforserver.h5

# %% [markdown]
# ###### loading label names

# %%
label_list_path = 'datasets/cifar-10-batches-py/batches.meta'

# %%
keras_dir = os.path.expanduser(os.path.join('~', '.keras'))
datadir_base = os.path.expanduser(keras_dir)
if not os.access(datadir_base, os.W_OK):
    datadir_base = os.path.join('/tmp', '.keras')
label_list_path = os.path.join(datadir_base, label_list_path)

# %%
with open(label_list_path, mode='rb') as f:
    labels = pickle.load(f)

# %%
predict_gen = model.predict(X_test)
print predict_gen.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-ee1e676873f6> in <module>()
# ----> 1 predict_gen = model.predict(X_test)
#       2 print predict_gen.shape
#
# NameError: name 'X_test' is not defined

# %%
for predict_index, predicted_y in enumerate(predict_gen):
    actual_label = labels['label_names'][np.argmax(y_test[predict_index])]
    predicted_label = labels['label_names'][np.argmax(predicted_y)]
    print('Actual Label = %s vs. Predicted Label = %s' % (actual_label,
                                                          predicted_label))
    if predict_index == num_predictions:
        break
# Out:
# Actual Label = cat vs. Predicted Label = cat
# Actual Label = ship vs. Predicted Label = ship
# Actual Label = ship vs. Predicted Label = ship
# Actual Label = airplane vs. Predicted Label = airplane
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = automobile vs. Predicted Label = automobile
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = cat vs. Predicted Label = cat
# Actual Label = automobile vs. Predicted Label = automobile
# Actual Label = airplane vs. Predicted Label = cat
# Actual Label = truck vs. Predicted Label = truck
# Actual Label = dog vs. Predicted Label = dog
# Actual Label = horse vs. Predicted Label = horse
# Actual Label = truck vs. Predicted Label = truck
# Actual Label = ship vs. Predicted Label = ship
# Actual Label = dog vs. Predicted Label = dog
# Actual Label = horse vs. Predicted Label = horse
# Actual Label = ship vs. Predicted Label = ship
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = horse vs. Predicted Label = horse
# Actual Label = airplane vs. Predicted Label = airplane
# Actual Label = deer vs. Predicted Label = deer
# Actual Label = truck vs. Predicted Label = truck
# Actual Label = dog vs. Predicted Label = deer
# Actual Label = bird vs. Predicted Label = bird
# Actual Label = deer vs. Predicted Label = deer
# Actual Label = airplane vs. Predicted Label = airplane
# Actual Label = truck vs. Predicted Label = truck
# Actual Label = frog vs. Predicted Label = frog
# Actual Label = frog vs. Predicted Label = frog

# %% [markdown]
# ###### Testing for a single image

# %%
#testing for a single image
from keras.preprocessing import image as image_utils
test_image = image_utils.load_img('dog.jpeg', target_size=(32, 32))
test_image = image_utils.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = model.predict_on_batch(test_image)


#print(result)
predicted_label = labels['label_names'][np.argmax(result)]
print (predicted_label)
# Out:
# dog

# %% [markdown]
# # For Demonstration

# %% [markdown]
# ###### loading model

# %%
from keras.models import load_model

# %%
model = load_model('/home/shuja1497/study/OpenSourceProject/server/saved_models/modelforserver.h5')

# %%
print model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 12, 12, 128)       73856
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 776,394
# Trainable params: 776,394
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.layers import Activation

# %%
def create_model(): 
    model = Sequential()
    model.add(Dense(64, input_dim=14, init='uniform'))
    model.add(LeakyReLU(alpha=0.3))
    model.add(BatchNormalization(epsilon=1e-06, mode=0, momentum=0.9, weights=None))
    model.add(Dropout(0.5)) 
    model.add(Dense(64, init='uniform'))
    model.add(LeakyReLU(alpha=0.3))
    model.add(BatchNormalization(epsilon=1e-06, mode=0, momentum=0.9, weights=None))
    model.add(Dropout(0.5))
    model.add(Dense(2, init='uniform'))
    model.add(Activation('softmax'))
    return model

# %%
model = create_model()
model.summary()
# Out:
# /home/shujareshi/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(64, kernel_initializer="uniform", input_dim=14)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/shujareshi/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(epsilon=1e-06, weights=None, momentum=0.9)`
#   """
# /home/shujareshi/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(64, kernel_initializer="uniform")`
#   import sys
# /home/shujareshi/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `BatchNormalization` call to the Keras 2 API: `BatchNormalization(epsilon=1e-06, weights=None, momentum=0.9)`
#   if __name__ == '__main__':
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 64)                960
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                4160
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 2)                 130
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 5,762
# Trainable params: 5,506
# Non-trainable params: 256
# _________________________________________________________________
# /home/shujareshi/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(2, kernel_initializer="uniform")`
#   # This is added back by InteractiveShellApp.init_path()

# %%
#model.load_weights('final_cifar10_trained_model.h5')

# %%
from keras.models import load_model
model = load_model('modelforserver.h5')
# Out:
# Using Theano backend.

# %%
import numpy as np

# %%
#testing for a single image
from keras.preprocessing import image as image_utils
test_image = image_utils.load_img('testSET/one.png', target_size=(32, 32))
test_image = image_utils.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = model.predict_on_batch(test_image)


#print(result)
predicted_label = labels['label_names'][np.argmax(result)]
print (predicted_label)
# Out:
# truck
